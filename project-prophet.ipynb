# %%
import pandas as pd
import numpy as np
# Load the BTC dataset
column_names = ['timestamp', 'open', 'high', 'low', 'close', 'volume', 'close_time', 'quote_asset_volume', 'number_of_trades', 'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'ignore']

df = pd.read_csv('/content/BNBUSDT (1).csv', header=None, names=column_names)

# Display the first few rows of the data
df.head()
# Out:
# /tmp/ipython-input-1-1855742643.py:6: DtypeWarning: Columns (1,2,3,4,5,7,8,9,10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/BNBUSDT (1).csv', header=None, names=column_names)
#              timestamp  open  high  low  close  volume  \
# 0            timestamp  open  high  low  close  volume
# 1  2017-11-06 03:54:00   1.5   1.5  1.5    1.5   10.83
# 2  2017-11-06 03:55:00   1.3   1.3  1.3    1.3     1.0
# 3  2017-11-06 03:56:00   1.3   1.3  0.5    0.5    19.0
# 4  2017-11-06 03:57:00   0.5  0.61  0.5   0.61   253.0
#
#                 close_time  quote_asset_volume  number_of_trades  \
# 0               close_time  quote_asset_volume  number_of_trades
# 1  2017-11-06 03:54:59.999              16.245                 2
# 2  2017-11-06 03:55:59.999                 1.3                 1
# 3  2017-11-06 03:56:59.999              24.356                 6
# 4  2017-11-06 03:57:59.999              151.66                17
#
# ...

# %%
# Check data types
print("Data types of each column:")
print(df.dtypes)
# Out:
# Data types of each column:
# timestamp                       object
# open                            object
# high                            object
# low                             object
# close                           object
# volume                          object
# close_time                      object
# quote_asset_volume              object
# number_of_trades                object
# taker_buy_base_asset_volume     object
# taker_buy_quote_asset_volume    object
# ignore                          object
# dtype: object

# %%
# Step 1: Identify columns to convert
numeric_columns = ['open', 'high', 'low', 'close', 'volume',
                   'quote_asset_volume', 'number_of_trades',
                   'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume']

# Step 2: Convert object columns to numeric
for col in numeric_columns:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# Step 3: Check for NaN values
print("NaN values in each column after conversion:")
print(df.isna().sum())

# Step 4: Handle NaN values (example: fill with 0 or drop rows)
df.fillna(0, inplace=True)
# Alternatively, to drop rows with NaN values
# df.dropna(inplace=True)

# Verify the data types after conversion
print("Data types after conversion:")
print(df.dtypes)
# Out:
# NaN values in each column after conversion:
# timestamp                       0
# open                            1
# high                            1
# low                             1
# close                           1
# volume                          1
# close_time                      0
# quote_asset_volume              1
# number_of_trades                1
# taker_buy_base_asset_volume     1
# taker_buy_quote_asset_volume    1
# ignore                          0
# dtype: int64
# Data types after conversion:
# timestamp                        object
# open                            float64
# high                            float64
# low                             float64
# close                           float64
# volume                          float64
# close_time                       object
# quote_asset_volume              float64
# number_of_trades                float64
# taker_buy_base_asset_volume     float64
# taker_buy_quote_asset_volume    float64
# ...

# %%
# Display the columns of the DataFrame
print(df.columns)

# Display the first few rows of the DataFrame
print(df.head())
# Out:
# Index(['timestamp', 'open', 'high', 'low', 'close', 'volume', 'close_time',
#        'quote_asset_volume', 'number_of_trades', 'taker_buy_base_asset_volume',
#        'taker_buy_quote_asset_volume', 'ignore'],
#       dtype='object')
#              timestamp  open  high  low  close  volume  \
# 0            timestamp   0.0  0.00  0.0   0.00    0.00
# 1  2017-11-06 03:54:00   1.5  1.50  1.5   1.50   10.83
# 2  2017-11-06 03:55:00   1.3  1.30  1.3   1.30    1.00
# 3  2017-11-06 03:56:00   1.3  1.30  0.5   0.50   19.00
# 4  2017-11-06 03:57:00   0.5  0.61  0.5   0.61  253.00
#
#                 close_time  quote_asset_volume  number_of_trades  \
# 0               close_time               0.000               0.0
# 1  2017-11-06 03:54:59.999              16.245               2.0
# 2  2017-11-06 03:55:59.999               1.300               1.0
# 3  2017-11-06 03:56:59.999              24.356               6.0
# 4  2017-11-06 03:57:59.999             151.660              17.0
#
# ...

# %%
# Display rows with NaN values
print(df[df.isna().any(axis=1)])
# Out:
# Empty DataFrame
# Columns: [timestamp, open, high, low, close, volume, close_time, quote_asset_volume, number_of_trades, taker_buy_base_asset_volume, taker_buy_quote_asset_volume, ignore]
# Index: []

# %%
# Drop rows with any NaN values
df_cleaned = df.dropna()

# %%
# Check the first few values in the timestamp column
print(df['timestamp'].head())
# Out:
# 0              timestamp
# 1    2017-11-06 03:54:00
# 2    2017-11-06 03:55:00
# 3    2017-11-06 03:56:00
# 4    2017-11-06 03:57:00
# Name: timestamp, dtype: object

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Make predictions on the prophet_df_subset (the training data)
forecast_subset = model.predict(prophet_df_subset)

# Merge the actual values with the predictions
evaluation_subset_df = prophet_df_subset.merge(forecast_subset[['ds', 'yhat']], on='ds', how='left')

# Calculate evaluation metrics on the subset
mae_subset = mean_absolute_error(evaluation_subset_df['y'], evaluation_subset_df['yhat'])
mse_subset = mean_squared_error(evaluation_subset_df['y'], evaluation_subset_df['yhat'])
rmse_subset = np.sqrt(mse_subset)

print(f"Metrics on prophet_df_subset (Training Data):")
print(f"Mean Absolute Error (MAE): {mae_subset}")
print(f"Mean Squared Error (MSE): {mse_subset}")
print(f"Root Mean Squared Error (RMSE): {rmse_subset}")

# Calculate precision metric (Standard Deviation of Errors) on the subset
errors_subset = evaluation_subset_df['y'] - evaluation_subset_df['yhat']
precision_subset_metric = np.std(errors_subset)

print(f"Standard Deviation of Errors (a measure of precision): {precision_subset_metric}")
# Out:
# Metrics on prophet_df_subset (Training Data):
# Mean Absolute Error (MAE): 9.522885202432633
# Mean Squared Error (MSE): 158.56627514709032
# Root Mean Squared Error (RMSE): 12.592310159263484
# Standard Deviation of Errors (a measure of precision): 12.592310046690967
